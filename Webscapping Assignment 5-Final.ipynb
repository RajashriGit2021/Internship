# %% [markdown]
# # WEB SCRAPING – ASSIGNMENT 4

# %% [raw]
# Read all the problem statements, notes carefully and scrape the required data using any web scraping tool of your choice.
#  You have to handle commonly occurring EXCEPTIONS by using exception handling programing. To get information about selenium Exceptions. You may visit following links:
# 1. https://selenium-python.readthedocs.io/api.html
# 2. https://www.guru99.com/exception-handling-selenium.html
# 3. https://stackoverflow.com/questions/38022658/selenium-python-handling-no-such-element-exception/38023345

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/ You need to find following details: A) Rank B) Name C) Artist D) Upload date E) Views

# %%
import selenium
from selenium import webdriver
import pandas as pd
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
time.sleep(3)
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
count = 0
#creating list for rank, uploader name, video name, no of views, date of upload
Rank = []
video_names = []
Artist = []
views = []
upload_dates = []
    #RANK ELEMENT
try:
    rank_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')[:30]
    for i in rank_obj:
        Rank.append(i.text)
except NoSuchElementException :
    Rank.append('-')
   #VIDEO NAME ELEMENT
try:
    videoname_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')[:30]
    for i in videoname_obj:
        video_names.append(i.text.split('[')[0][1:-1]) #extract only name from text remove []
except NoSuchElementException :
    video_names.append('-')

    #UPLOADER_OF_VIDEO
try:
    Artist1 = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')[:30]
    for i in Artist1:
        Artist.append(i.text)
except NoSuchElementException :
    Artist.append('-')

    #VIEWS ON THE VIDEOS
try:
    view_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')[:30]
    for i in view_obj:
        views.append(i.text)
except NoSuchElementException :
    views.append('-')
        
    #DATE OF THE VIDEO ELEMENT
try:
    date_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')[:30]
    for i in date_obj:
        upload_dates.append(i.text)
except NoSuchElementException :
    upload_dates.append('-')
    
# creating a diction of all the columns
dict = {'rank':Rank, 'video_name':video_names,'Artist':Artist,'Upload date':upload_dates,'Views(Billions)':views}
# CREATING TABLE / dATA fRAME OF THE DICTIONARY
Data = pd.DataFrame(dict)
Data
# Out:
#    rank                                 video_name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                       Johny Johny Yes Papa
# 3    4.                               Shape of You
# 4    5.                              See You Again
# 5    6.                                  Bath Song
# 6    7.  Learning Colors – Colorful Eggs on a Farm
# 7    8.   Masha and the Bear – Recipe for Disaster
# 8    9.                                Uptown Funk
# 9   10.                Phonics Song with Two Words
# 10  11.                              Gangnam Style
# 11  12.                             Dame Tu Cosita
# 12  13.                                      Sugar
# 13  14.                                      Sorry
# 14  15.                                       Roar
# 15  16.                             Counting Stars
# 16  17.                          Thinking Out Loud
# 17  18.                          Wheels on the Bus
# 18  19.                                 Dark Horse
# 19  20.                                      Faded
# 20  21.                             Girls Like You
# 21  22.                                    Lean On
# 22  23.                                   Bailando
# 23  24.                               Shake It Off
# 24  25.                                 Let Her Go
# 25  26.                                     Axel F
# 26  27.                                   Mi Gente
# 27  28.                                    Perfect
# 28  29.           Waka Waka (This Time for Africa)
# 29  30.                                      Hello
#
#                                          Artist        Upload date  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                    Luis Fonsi   January 12, 2017
# 2                                   LooLoo Kids    October 8, 2016
# 3                                    Ed Sheeran   January 30, 2017
# 4                                   Wiz Khalifa      April 6, 2015
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018
# 6                                   Miroshka TV  February 27, 2018
# 7                                    Get Movies   January 31, 2012
# 8                                   Mark Ronson  November 19, 2014
# 9                                     ChuChu TV      March 6, 2014
# 10                                          Psy      July 15, 2012
# 11                                    El Chombo      April 5, 2018
# 12                                     Maroon 5   January 14, 2015
# 13                                Justin Bieber   October 22, 2015
# 14                                   Katy Perry  September 5, 2013
# 15                                  OneRepublic       May 31, 2013
# 16                                   Ed Sheeran    October 7, 2014
# 17                   Cocomelon – Nursery Rhymes       May 24, 2018
# 18                                   Katy Perry  February 20, 2014
# 19                                  Alan Walker   December 3, 2015
# 20                                     Maroon 5       May 31, 2018
# 21                                  Major Lazer     March 22, 2015
# 22                             Enrique Iglesias     April 11, 2014
# 23                                 Taylor Swift    August 18, 2014
# 24                                    Passenger      July 25, 2012
# 25                                   Crazy Frog      June 16, 2009
# 26                                     J Balvin      June 29, 2017
# 27                                   Ed Sheeran   November 9, 2017
# 28                                      Shakira       June 4, 2010
# 29                                        Adele   October 22, 2015
#
#    Views(Billions)
# 0             9.44
# 1             7.57
# 2             5.77
# 3             5.48
# 4             5.28
# 5             4.55
# 6             4.52
# 7             4.46
# 8             4.32
# 9             4.22
# 10            4.21
# 11            3.63
# 12            3.56
# 13            3.47
# 14            3.44
# 15            3.41
# 16            3.34
# 17            3.29
# 18            3.15
# 19            3.15
# 20            3.14
# 21            3.10
# 22            3.10
# 23            3.10
# 24            3.09
# 25            3.03
# 26            2.99
# 27            2.97
# 28            2.96
# 29            2.89

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'https://www.bcci.tv/'
driver.get(url)

# %%
internation_fixtures_obj = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[2]/nav/ul/li[1]/div[2]/div/ul/li[1]/a')
# dorpdown element international fixtures.
link = internation_fixtures_obj.get_attribute('href')
driver.get(link)

# %%
date = []
time = []
series = []
place = []
match_title = []
match_details = []
# combine Month and Day for Date list
try :
    month_obj = driver.find_elements_by_xpath('//span[@class="fixture__month"]')
    day_obj = driver.find_elements_by_xpath('//span[@class="fixture__date"]')
    for i in range(len(month_obj)):
        date.append(str(day_obj[i].text)+' '+str(month_obj[i].text).lower())
except NoSuchElementException:
    date.append('-')
    
# Time of match  
try :
    time_obj = driver.find_elements_by_xpath('//span[@class="fixture__time"]')
    
    for i in range(len(time_obj)):
        time.append(str(time_obj[i].text))
except NoSuchElementException:
    time.append('-')

#series details and Match Tittle

try :
    series_obj = driver.find_elements_by_xpath('//span[@class="u-unskewed-text fixture__format"]')
    title_obj = driver.find_elements_by_xpath('//span[@class="u-unskewed-text fixture__tournament-label u-truncated"]')
    for i in range(len(month_obj)):
        series.append(str(series_obj[i].text)+' '+str(title_obj[i].text))
        match_title.append(str(title_obj[i].text))
except NoSuchElementException:
    series.append('-')

    
# Location of MAtch, and series information
try :
    location_obj = driver.find_elements_by_xpath('//p[@class="fixture__additional-info"]/span')
    match_name_obj = driver.find_elements_by_xpath('//strong[@class="fixture__name fixture__name--with-margin"]')
    for i in range(len(time_obj)):
        place.append(str(location_obj[i].text))
        match_details.append(match_name_obj[i].text)
except NoSuchElementException:
    place.append ('-')

#creating the dictionary of the elements
dict= {
    'Match Title': match_title,'Series':series,'Match Location':place,'Date':date,'Time':time,
    'series details': match_details
}

#Fixtures creating with creating a DataFrame
Fixtures = pd.DataFrame(dict)
Fixtures
# Out:
#                        Match Title                               Series  \
# 0     2021 ICC MEN'S T20 WORLD CUP    T20I 2021 ICC MEN'S T20 WORLD CUP
# 1     2021 ICC MEN'S T20 WORLD CUP    T20I 2021 ICC MEN'S T20 WORLD CUP
# 2     2021 ICC MEN'S T20 WORLD CUP    T20I 2021 ICC MEN'S T20 WORLD CUP
# 3     2021 ICC MEN'S T20 WORLD CUP    T20I 2021 ICC MEN'S T20 WORLD CUP
# 4     2021 ICC MEN'S T20 WORLD CUP    T20I 2021 ICC MEN'S T20 WORLD CUP
# 5         INDIA V NEW ZEALAND 2021        T20I INDIA V NEW ZEALAND 2021
# 6         INDIA V NEW ZEALAND 2021        T20I INDIA V NEW ZEALAND 2021
# 7         INDIA V NEW ZEALAND 2021        T20I INDIA V NEW ZEALAND 2021
# 8         INDIA V NEW ZEALAND 2021        TEST INDIA V NEW ZEALAND 2021
# 9         INDIA V NEW ZEALAND 2021        TEST INDIA V NEW ZEALAND 2021
# 10  SOUTH AFRICA V INDIA 2021/2022  TEST SOUTH AFRICA V INDIA 2021/2022
# 11  SOUTH AFRICA V INDIA 2021/2022  TEST SOUTH AFRICA V INDIA 2021/2022
# 12  SOUTH AFRICA V INDIA 2021/2022  TEST SOUTH AFRICA V INDIA 2021/2022
# 13  SOUTH AFRICA V INDIA 2021/2022   ODI SOUTH AFRICA V INDIA 2021/2022
# 14  SOUTH AFRICA V INDIA 2021/2022   ODI SOUTH AFRICA V INDIA 2021/2022
# 15  SOUTH AFRICA V INDIA 2021/2022   ODI SOUTH AFRICA V INDIA 2021/2022
# 16  SOUTH AFRICA V INDIA 2021/2022  T20I SOUTH AFRICA V INDIA 2021/2022
# 17  SOUTH AFRICA V INDIA 2021/2022  T20I SOUTH AFRICA V INDIA 2021/2022
# 18  SOUTH AFRICA V INDIA 2021/2022  T20I SOUTH AFRICA V INDIA 2021/2022
# 19  SOUTH AFRICA V INDIA 2021/2022  T20I SOUTH AFRICA V INDIA 2021/2022
#
#                                 Match Location         Date       Time  \
# 0           Dubai International Stadium, Dubai   24 october  19:30 IST
# 1           Dubai International Stadium, Dubai   31 october  19:30 IST
# 2             Zayed Cricket Stadium, Abu Dhabi  03 november  19:30 IST
# 3           Dubai International Stadium, Dubai  05 november  19:30 IST
# 4           Dubai International Stadium, Dubai  08 november  19:30 IST
# 5               Sawai Mansingh Stadium, Jaipur  17 november  19:00 IST
# 6   JSCA International Stadium Complex, Ranchi  19 november  19:00 IST
# 7                        Eden Gardens, Kolkata  21 november  19:00 IST
# 8                           Green Park, Kanpur  25 november  09:30 IST
# 9                     Wankhede Stadium, Mumbai  03 december  09:30 IST
# 10         New Wanderers Stadium, Johannesburg  17 december  13:30 IST
# 11                  Supersport Park, Centurion  26 december  13:30 IST
# 12         New Wanderers Stadium, Johannesburg   03 january  13:30 IST
# 13                          Boland Park, Paarl   11 january  14:00 IST
# 14                         Newlands, Cape Town   14 january  14:00 IST
# 15                         Newlands, Cape Town   16 january  14:00 IST
# 16                         Newlands, Cape Town   19 january  19:30 IST
# 17                         Newlands, Cape Town   21 january  19:30 IST
# 18                          Boland Park, Paarl   23 january  19:30 IST
# 19                          Boland Park, Paarl   26 january  19:30 IST
#
#    series details
# 0        Match 16
# 1        Match 28
# 2        Match 33
# 3        Match 37
# 4        Match 42
# 5        1st T20I
# 6        2nd T20I
# 7        3rd T20I
# 8        1st Test
# 9        2nd Test
# 10       1st Test
# 11       2nd Test
# 12       3rd Test
# 13        1st ODI
# 14        2nd ODI
# 15        3rd ODI
# 16       1st T20I
# 17       2nd T20I
# 18       3rd T20I
# 19       4th T20I

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'https://www.guru99.com/'
driver.get(url)
#clicking on Selenium tutorial
driver.find_element_by_xpath("//div[@class='srch']/span[8]/a").click()
# finding the link of Selenium Common Exceptions list and gettting its url and loading it to the web browser
exception_link = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a")
driver.get(exception_link.get_attribute('href'))
# All datas are available in table format , no missing vlaues to cause exceptions.
row_obj = driver.find_elements_by_xpath('//table[@class="table table-striped"]')

# %%
name = []
description = []
table =driver.find_elements_by_xpath('//table[@class="table table-striped"]//tr//td[1]')
desc =driver.find_elements_by_xpath('//table[@class="table table-striped"]//tr//td[2]')

for i in table:
    name.append(i.text)
for j in desc:
    description.append(j.text)
exceptions = pd.DataFrame({})
exceptions['Exception name'] = name[1:]
exceptions['Exception Description'] =description[1:]
exceptions
# Out:
#                          Exception name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                                 Exception Description
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'http://statisticstimes.com/'
driver.get(url)

# %%
#finding the link of Economy of India
india_economy_page = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
#extracting the url from the element
link  = india_economy_page.get_attribute('href')
#giving the india economy url to the browser
driver.get(link)
#Click the State-wise gdp of india element
driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# %%
ranks = []
states = []
GSDP_current_price_19_20 = []
GSDP_current_price_18_19 = []
share_18_19 = []
gdp_19 = []

    #Rank Element

try:
    rank_element = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[1]')
    for i in rank_element:
        ranks.append(i.text)
except NoSuchElementException:
    ranks.append('-')
    
    #State Element

try:
    state_element = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[2]')
    for i in state_element:
        states.append(i.text)
except NoSuchElementException:
    states.append('-')
   
    
    #GSDP 19-20 element

try:
    GSDP_19_20_element = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[3]')
    for i in GSDP_19_20_element:
        GSDP_current_price_19_20.append(i.text)
except NoSuchElementException:
    GSDP_current_price_19_20.append('-')
    
     #GSDP 18-19 element
    
try:
    GSDP_18_19_element = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[4]')
    for i in GSDP_18_19_element:
        GSDP_current_price_18_19.append(i.text)
except NoSuchElementException:
    GSDP_current_price_18_19.append('-')
    
    
    #share element for 18-19
    
try:
    share_element = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[5]')
    for i in share_element:
        share_18_19.append(i.text)
except NoSuchElementException:
    share_18_19.append('-')
    
    
    #GDP of 2019
    
try:
    GDP_element = driver.find_elements_by_xpath('/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[6]')
    for i in GDP_element:
        gdp_19.append(i.text)
except NoSuchElementException:
    gdp_19.append('-')

# %%
#Creating a Dictionarty of the all the elements
dict = {
    'Rank':ranks, 'State Name':states,'GSDP_current_price_19_20': GSDP_current_price_19_20,'GSDP_current_price_18_19':GSDP_current_price_18_19,
    'Share_18_19':share_18_19,'GDP($ billion)':gdp_19
    }

#loading the dictionary to a dataframe 
table = pd.DataFrame(dict)
table
# Out:
#    Rank                 State Name GSDP_current_price_19_20  \
# 0     1                Maharashtra                        -
# 1     2                 Tamil Nadu                1,845,853
# 2     3              Uttar Pradesh                1,687,818
# 3     4                    Gujarat                        -
# 4     5                  Karnataka                1,631,977
# 5     6                West Bengal                1,253,832
# 6     7                  Rajasthan                1,020,989
# 7     8             Andhra Pradesh                  972,782
# 8     9                  Telangana                  969,604
# 9    10             Madhya Pradesh                  906,672
# 10   11                     Kerala                        -
# 11   12                      Delhi                  856,112
# 12   13                    Haryana                  831,610
# 13   14                      Bihar                  611,804
# 14   15                     Punjab                  574,760
# 15   16                     Odisha                  521,275
# 16   17                      Assam                        -
# 17   18               Chhattisgarh                  329,180
# 18   19                  Jharkhand                  328,598
# 19   20                Uttarakhand                        -
# 20   21            Jammu & Kashmir                        -
# 21   22           Himachal Pradesh                  165,472
# 22   23                        Goa                   80,449
# 23   24                    Tripura                   55,984
# 24   25                 Chandigarh                        -
# 25   26                 Puducherry                   38,253
# 26   27                  Meghalaya                   36,572
# 27   28                     Sikkim                   32,496
# 28   29                    Manipur                   31,790
# 29   30                   Nagaland                        -
# 30   31          Arunachal Pradesh                        -
# 31   32                    Mizoram                   26,503
# 32   33  Andaman & Nicobar Islands                        -
#
#    GSDP_current_price_18_19 Share_18_19 GDP($ billion)
# 0                 2,632,792      13.94%        399.921
# 1                 1,630,208       8.63%        247.629
# 2                 1,584,764       8.39%        240.726
# 3                 1,502,899       7.96%        228.290
# 4                 1,493,127       7.91%        226.806
# 5                 1,089,898       5.77%        165.556
# 6                   942,586       4.99%        143.179
# 7                   862,957       4.57%        131.083
# 8                   861,031       4.56%        130.791
# 9                   809,592       4.29%        122.977
# 10                  781,653       4.14%        118.733
# 11                  774,870       4.10%        117.703
# 12                  734,163       3.89%        111.519
# 13                  530,363       2.81%         80.562
# 14                  526,376       2.79%         79.957
# 15                  487,805       2.58%         74.098
# 16                  315,881       1.67%         47.982
# 17                  304,063       1.61%         46.187
# 18                  297,204       1.57%         45.145
# 19                  245,895       1.30%         37.351
# 20                  155,956       0.83%         23.690
# 21                  153,845       0.81%         23.369
# 22                   73,170       0.39%         11.115
# 23                   49,845       0.26%          7.571
# 24                   42,114       0.22%          6.397
# 25                   34,433       0.18%          5.230
# 26                   33,481       0.18%          5.086
# 27                   28,723       0.15%          4.363
# 28                   27,870       0.15%          4.233
# 29                   27,283       0.14%          4.144
# 30                   24,603       0.13%          3.737
# 31                   22,287       0.12%          3.385
# 32                        -           -              -

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'https://github.com/'
driver.get(url)
#find the element of the Trending from the dropdown of the EXPLORE column and extracting the URL of trending

link_trending = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a').get_attribute('href')
link_trending
# Out:
# 'https://github.com/trending'

# %%
#feeding the trending url to the browser

driver.get(link_trending)
repo_titles = []

repo_urls = []

#Extraction Repository Name and its corresponding urls
title_element = driver.find_elements_by_xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article/h1/a')
for i in title_element:
    repo_urls.append(i.get_attribute('href'))
    repo_titles.append(i.text)

# %%
repo_descriptions = []
contributors_counts = []
language_used  = []

#LOOPING THROUGH THE REPOSITORY URLS TO EXTRACT DATA FROM EACH LINK>

for  i in repo_urls:
    
    #loading the repositroy link to the browsetr
    driver.get(i)
    #waitng for the browser to load and keep the browser to sleep mode for 2 sec
    #DESCRIPTION OF REPOSITORY
    try :
        description_element = driver.find_element_by_xpath('//*[@id="repo-content-pjax-container"]/div/div[2]/div[2]/div/div[1]/div/p')
        
        repo_descriptions.append(description_element.text)
    except NoSuchElementException:
        repo_descriptions.append('-')

    #CONTRIBUTORS_cOUNT
    try :
        contributors_element = driver.find_element_by_xpath('/html/body/div[4]/div/main/div[2]/div/div/div[2]/div[2]/div/div[5]/div/h2/a/span')
       
        contributors_counts.append(contributors_element.text)
    except NoSuchElementException:
        contributors_counts.append('-')

    #LANGUAGES used

    try :
        language_element = driver.find_elements_by_xpath('//*[@id="repo-content-pjax-container"]/div/div[2]/div[2]/div/div[1]/div/div[1]/div/a')
        li = []
        for i in language_element:
           
            li.append(i.text)
        language_used.append(', '.join(li))
    except NoSuchElementException:
        language_used.append('-')

#creating a dictionary of all the elements
dict={
    'Repository Title': repo_titles,
    'Repository Description':repo_descriptions,
    'Contributors Count': contributors_counts,
    'Languages Used': language_used,

}

table = pd.DataFrame(dict)
table
# Out:
#                       Repository Title  \
# 0            peng-zhihui / Dummy-Robot
# 1                   trailofbits / algo
# 2               Snailclimb / JavaGuide
# 3               louislam / uptime-kuma
# 4                     vuejs / vue-next
# 5                babysor / MockingBird
# 6                   facebook / flipper
# 7                       fatedier / frp
# 8                          ossrs / srs
# 9               vinta / awesome-python
# 10                     yt-dlp / yt-dlp
# 11              ihciah / clean-dns-bpf
# 12             sdras / awesome-actions
# 13  Hack-with-Github / Awesome-Hacking
# 14             anncwb / vue-vben-admin
# 15   Python-World / Python_and_the_Web
# 16              wimpysworld / quickemu
# 17        mattiasgustavsson / dos-like
# 18                   apache / rocketmq
# 19                   donet5 / WebFirst
# 20      raywenderlich / flta-materials
# 21                        herosi / CTO
# 22                  alibaba / Sentinel
# 23      alibaba / spring-cloud-alibaba
# 24                         vuejs / vue
#
#                                Repository Description Contributors Count  \
# 0                                      我的超迷你机械臂机器人项目。                  -
# 1                  Set up a personal VPN in the cloud                156
# 2   「Java学习+面试指南」一份涵盖大部分 Java 程序员所需要掌握的核心知识。准备 Jav...                261
# 3                 A fancy self-hosted monitoring tool                  -
# 4   🖖 Vue.js is a progressive, incrementally-adopt...                 64
# 5   🚀AI拟声: 5秒内克隆您的声音并生成任意语音内容 Clone a voice in 5 s...                  -
# 6   A desktop debugging platform for mobile develo...                219
# 7   A fast reverse proxy to help you expose a loca...                 14
# 8   SRS is a simple, high efficiency and realtime ...                  -
# 9   A curated list of awesome Python frameworks, l...                  -
# 10  A youtube-dl fork with additional features and...                854
# 11                      基于 Rust + eBPF 丢弃 GFW DNS 污染包                  -
# 12  A curated list of awesome actions to use on Gi...                  -
# 13  A collection of various awesome lists for hack...                  -
# 14  A modern vue admin. It is based on Vue3, vite ...                 72
# 15  Build Bots, Scrape a website or use an API to ...                  -
# 16  Quickly create and run optimised Windows, macO...                 16
# 17  Engine for making things with a MS-DOS feel, b...                  -
# 18                          Mirror of Apache RocketMQ                280
# 19  .NET CORE 代码生成器 ，Web中使用CodeFirst模式， 实体生成器，UI代码...                  -
# 20  The projects and the materials that accompany ...                  8
# 21                               Call Tree Overviewer                  -
# 22  A powerful flow control component enabling rel...                152
# 23  Spring Cloud Alibaba provides a one-stop solut...                114
# 24  🖖 Vue.js is a progressive, incrementally-adopt...                401
#
#                                        Languages Used
# 0
# 1
# 2
# 3   docker, monitoring, responsive, single-page-ap...
# 4
# 5                  ai, deep-learning, speech, pytorch
# 6
# 7   go, tunnel, proxy, firewall, nat, http-proxy, ...
# 8
# 9
# 10
# 11
# 12  github, awesome, actions, awesome-list, curate...
# 13  android, security, awesome, reverse-engineerin...
# 14
# 15          python, api, fun, bots, scraping-websites
# 16
# 17
# 18                                           rocketmq
# 19
# 20
# 21
# 22
# 23
# 24

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'https://www.billboard.com/'
driver.get(url)
link = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/header/div/ul/li[1]/span/span/span/span[1]/ul/li[1]/a').get_attribute('href')

# %%
#loading the extracted link of the hot top 100
driver.get(link)
song = []
artist = []
last_week_rank = []
peak_rank = []
weeks_on_board = []

#SONG NAME ELEMENT EXTRACTION
try:
    song_name_obj = driver.find_elements_by_xpath('//span[@class="chart-element__information"]/span[1]')
   
    for i in range(len(song_name_obj)):
        song.append(song_name_obj[i].text)
except NoSuchElementException:
    song.append('-')
    
    
#ARTIST NAME ELEMENT EXTRACTION
try:
   
    singer_name_obj = driver.find_elements_by_xpath('//span[@class="chart-element__information"]/span[2]')
    for i in range(len(singer_name_obj)):
        
        artist.append(singer_name_obj[i].text)
except NoSuchElementException:
    artist.append('-')
    
    
#LAST WEEK RANK of a SONG  ELEMENT EXTRACTION    
    #chart-element__metas chart-element__metas--large display--flex flex--y-center
try:
    rank_lastweek_obj = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--last"]')
   
    for i in range(len(rank_lastweek_obj)):
        last_week_rank.append(rank_lastweek_obj[i].text)
except NoSuchElementException:
    last_week_rank.append('-')
    
    
#PEAK RANK OF A SONG ELEMENT EXTRACTION    
try:
   
    peak_rank_obj = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--peak"]')
    for i in range(len(peak_rank_obj)):
        
        peak_rank.append(peak_rank_obj[i].text)
except NoSuchElementException:
     peak_rank.append('-')  
        
        
#WEEKS ON BOARD for a SONG ELEMENT EXTRACTION
try:
   
    no_of_weeks_onboard_obj = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--week"]')
    for i in range(len(no_of_weeks_onboard_obj)):
        
        weeks_on_board.append(no_of_weeks_onboard_obj[i].text)
except NoSuchElementException:
    weeks_on_board.append('-')

# %%
dict = {
    'Song Name': song, 'Artist Name':artist,
    'Last week Rank': last_week_rank,'Peak Rank':peak_rank,'Weeks on Board': weeks_on_board
}
table = pd.DataFrame(dict)
table
# Out:
#         Song Name                           Artist Name Last week Rank  \
# 0     My Universe                        Coldplay x BTS              -
# 1            Stay         The Kid LAROI & Justin Bieber              1
# 2   Industry Baby               Lil Nas X & Jack Harlow              2
# 3      Way 2 Sexy   Drake Featuring Future & Young Thug              3
# 4      Fancy Like                          Walker Hayes              5
# ..            ...                                   ...            ...
# 95      Pipe Down                                 Drake             68
# 96    Papi's Home                                 Drake             66
# 97         Chosen  Blxst & Tyga Featuring Ty Dolla $ign              -
# 98     Toxic Punk            YoungBoy Never Broke Again              -
# 99           Moon                            Kanye West             76
#
#    Peak Rank Weeks on Board
# 0          1              1
# 1          1             12
# 2          2             10
# 3          1              4
# 4          5             15
# ..       ...            ...
# 95        14              4
# 96         8              4
# 97        98              1
# 98        99              1
# 99        17              5
#
# [100 rows x 5 columns]

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code#

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'https://naukri.com'
driver.get(url)
#recruitor page link element
recruiter_link = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/ul[1]/li[2]/a').get_attribute('href')
#loading the recruitor link to the browser
driver.get(recruiter_link)
driver.current_url
# Out:
# 'https://www.naukri.com/hr-recruiters-consultants'

# %%
#element of Search tab and seARCH button
input_tab = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
search_btn = driver.find_element_by_xpath('//button[@class="fl qsbSrch blueBtn"]')
#sending keys to the Search Tab
input_tab.send_keys('Data Science')

#click the  search element
search_btn.click()
#extracting the link elements of the recruitors
recruiter_name = driver.find_elements_by_xpath("//p[@class='highlightable']/a[1]")
#Links of all the companies
all_recruitment_links = []
for i in recruiter_name:
    all_recruitment_links.append(i.get_attribute('href'))

# %%
re_names= []
re_company = []
re_location = []
re_skills = []
re_designation = []
#lopping through each company to extract data of each company seperately.
for i in range(50):
    driver.get(all_recruitment_links[i])
   
    
    #Recruiter Name
    try:
        name_element = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[2]/h1')
        re_names.append(name_element.text)
    except NoSuchElementException:
        re_names.append('-')
        
    #Company NAme
    try:
        company_element = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div[2]/p[1]')
        re_company.append(company_element.text)
    except NoSuchElementException:
        re_company.append('-')
    
    #Location element
    try:
        location_element = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[5]/a')
       # for i in location_element:
        re_location.append(location_element.text)
    except NoSuchElementException:
        re_location.append('-')
        
    #Skills
    try:
        skills_element = driver.find_elements_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div[1]/p')
        li = []
        for i in skills_element:
            li.append(i.text)
            
        temp = ' '.join(li) 
        re_skills.append(temp)
        
    except NoSuchElementException:
        re_skills.append('-')
      
    
    #Designation element
    try:
        designation_element = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[3]')
        re_designation.append(designation_element.text)
    except NoSuchElementException:
        re_designation.append('-')

# %%
#creating a dictionary of all the elements
dict = {
    'Recruiter Name': re_names,'Recruiter_Designation':re_designation,'Recruiter_Company':re_company,
    'Skills for hiring':re_skills,
    'Location':re_location
}
#creating a DataFrame/ Table of the dictionary
table = pd.DataFrame(dict)
table
# Out:
#                                        Recruiter Name  \
# 0                                        Aakash Harit
# 1                                shravan Kumar Gaddam
# 2                            MARSIAN Technologies LLP
# 3                                        Anik Agrawal
# 4                                           Narasimha
# 5                                        subhas patel
# 6   Abhishek - Only Analytics Hiring - India and APAC
# 7     Institute for Financial Management and Research
# 8                                         Balu Ramesh
# 9                                       Asif Lucknowi
# 10                                    InstaFinancials
# 11                                     Priyanka Akiri
# 12                                    Kalpana Dumpala
# 13                                            Mubarak
# 14                                     Kushal Rastogi
# 15                                        Ruchi Dhote
# 16                                 Mahesh Babu Channa
# 17                                       Kapil Devang
# 18                                      Manisha Yadav
# 19                                        Riya Rajesh
# 20                               Rashmi Bhattacharjee
# 21                                      Faizan Kareem
# 22                                     Rithika dadwal
# 23                                 Sandhya Khandagale
# 24                                          Shaun Rao
# 25                                      Azahar Shaikh
# 26                                              Manas
# 27                                              kumar
# 28                                       Sunil Vedula
# 29                                        Rajat Kumar
# 30                                        Priya Khare
# 31                                    Dhruv Dev Dubey
# 32                                          Jayanth N
# 33                                           SREEDHAR
# 34                                         Ravi Dubey
# 35                                  Radha Manivasagam
# 36                                      Prateek Kumar
# 37                                        Amit Sharma
# 38                                              Kanan
# 39                               Shashikant Chaudhary
# 40                                               Brad
# 41                                       Rutuja Pawar
# 42                                Madhusudhan Sridhar
# 43                                        Ankit Sinha
# 44                                     Gaurav Chouhan
# 45                                       Rashi Kacker
# 46                                            Ashwini
# 47                                       Balaji Kolli
# 48                                     Rajani Nagaraj
# 49                                        ROHIT Kumar
#
#                   Recruiter_Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                     Company Recruiter
# 5                         Founder & CEO
# 6         Recruitment - Lead Consultant
# 7                     Programme Manager
# 8                      HR Administrator
# 9                              Director
# 10                       Human Resource
# 11                           HR Manager
# 12                     Executive Hiring
# 13                           Company HR
# 14                           Company HR
# 15  Senior Executive Talent Acquisition
# 16                         HR Team Lead
# 17                           HR Manager
# 18                         HR Executive
# 19           Manager Talent Acquisition
# 20                              HR Head
# 21                           HR MANAGER
# 22                         HR Recruiter
# 23                         HR Recruiter
# 24            Manager - Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                        Founder & CEO
# 30                       Senior Manager
# 31             Company Recruitment Head
# 32                      Project Manager
# 33               Recruitment Consultant
# 34                  Recruitment Manager
# 35                         HR Executive
# 36                                 Head
# 37                           Consultant
# 38         senior technology instructor
# 39             HR Recruiter/HR Excutive
# 40        Manager, Technical Recruiting
# 41                  Technical Recruiter
# 42                      Erp Implementer
# 43                       Head-Analytics
# 44              Chief Technical Officer
# 45                   Sr Product Manager
# 46            Director, Global Delivery
# 47                           Co-Founder
# 48                           HR Manager
# 49                            Architect
#
#                                     Recruiter_Company  \
# 0                                Data Science Network
# 1      Shore Infotech India Pvt. Ltd (Since Dec-2016)
# 2           MARSIAN Technologies LLP (Since Feb-2016)
# 3               Enerlytics Software Solutions Pvt Ltd
# 4                                                   -
# 5                                     LibraryXProject
# 6   Apidel Technologies Division of Transpower (Si...
# 7                               IFMR (Since May-2017)
# 8        Techvantage Systems Pvt Ltd (Since Dec-2014)
# 9                                                   -
# 10                   CBL Data Science Private Limited
# 11             Infinitive Software Solutions Pvt.Ltd.
# 12                Innominds Software (Since Feb-2015)
# 13                                                  -
# 14                                                  -
# 15             Bristlecone India Ltd (Since Apr-2021)
# 16                 SocialPrachar.com (Since Jan-2014)
# 17                                     BISP Solutions
# 18                                           Easi Tax
# 19       Novelworx Digital Solutions (Since May-2019)
# 20       AXESTRACK SOFTWARE SOLUTIONS PRIVATE LIMITED
# 21                      FirstTech Consaltants Pvt.Ltd
# 22                                   Affine Analytics
# 23                    Compumatrice Multimedia Pvt Ltd
# 24                Exela Technologies (Since Nov-2014)
# 25                    NEAL ANALYTICS SERVICES PVT LTD
# 26    Autumn Leaf Consulting Services Private Limited
# 27                                            trainin
# 28                               Nanoprecise Sci Corp
# 29                         R.S Consultancy & Services
# 30                                                  -
# 31                      Confidential (Since Jun-2016)
# 32  Dollarbird Information Services Pvt, Ltd (Sinc...
# 33                                                  -
# 34                        HyrEzy Talent Solutions LLP
# 35                                         Techcovery
# 36                           Trisect (Since Jan-2013)
# 37                                                  -
# 38                                            NY INST
# 39                                                  -
# 40                       O.C. Tanner (Since Jan-2019)
# 41                     Demand Matrix (Since Feb-2018)
# 42                                                  -
# 43                                                  -
# 44                           Strategic Consulting Lab
# 45                               Impel Labs Pvt. Ltd.
# 46                                                  -
# 47                                                  -
# 48                                        WildJasmine
# 49               LNT Private Limited (Since Jul-2017)
#
#                                     Skills for hiring  \
# 0   Classic ASP Developer , Internet Marketing Pro...
# 1   .Net , Java , Data Science , Linux Administrat...
# 2                           Mid Level, Junior Level
# 3   , Mean Stack , javascript , angularjs , mongod...
# 4                         Step Next Private Limited
# 5   Hadoop , Spark , Digital Strategy , Data Archi...
# 6   Analytics , Business Intelligence , Business A...
# 7                   Analytics & Business Intelligence
# 8   Machine Learning , algorithms , Go Getter , Co...
# 9                        Weupskill- Live Wire India
# 10                          Junior Level, Mid Level
# 11                           Mid Level, High Level
# 12  Qa , Ui , ux , Java Developer , Java Architect...
# 13                                         MoneyTap
# 14               QuantMagnum Technologies Pvt. Ltd.
# 15                                        IT Skills
# 16                          Junior Level, Mid Level
# 17  Big Data , Hadoop , Data Analytics , Data Science
# 18                                        Mid Level
# 19                      IT-Software/Software Services
# 20                   Mid Level, Top Mangement Level
# 21  Data Analytics , Data Science , Machine Learni...
# 22                           Junior Level, Mid Level
# 23                              High Level, Mid Level
# 24  Java , Net , Angularjs , Hr , Infrastructure ,...
# 25                            Mid Level, High Level
# 26                  High Level, Top Mangement Level
# 27  Data Science , Hadoop , Rpas , Devops , Python...
# 28  Signal Processing , Machine Learning , Neural ...
# 29  Web Technologies , Project Management , Softwa...
# 30                           Independent Consultant
# 31  S. Finance Manager , Freshers , Experience , S...
# 32   Data Analytics , Managed Services , Team Leading
# 33      JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
# 34                  Mid Level, Top Mangement Level
# 35                                     Junior Level
# 36                                     Junior Level
# 37                                  ASCO consulting
# 38                          Mid Level, Junior Level
# 39  3D India Staffing Research & Consulting Co. In...
# 40                        Junior Level, High Level
# 41     Python , Php , Qa Automation , Ui , Wordpre
# 42                              MADHUSUDHAN SRIDHAR
# 43                  Suntech Global (Since Feb-2018)
# 44                Top Mangement Level, Junior Level
# 45               Data Science , Node.js , Angularjs
# 46                    MRP Advisers (Since Oct-2017)
# 47                    Saras Solutions India Pvt Ltd
# 48  java , hadoop , r , Machine Learning , spark ,...
# 49                            Mid Level, High Level
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4   Hyderabad / Secunderabad
# 5              UK - (london)
# 6          Vadodara / Baroda
# 7                    Chennai
# 8                 Trivandrum
# 9                     Indore
# 10     Bengaluru / Bangalore
# 11                 Hyderabad
# 12  Hyderabad / Secunderabad
# 13     Bengaluru / Bangalore
# 14                    Mumbai
# 15                      Pune
# 16  Hyderabad / Secunderabad
# 17                    Bhopal
# 18               Navi Mumbai
# 19                    Cochin
# 20                     Delhi
# 21  Hyderabad / Secunderabad
# 22                      Pune
# 23                      Pune
# 24                      Pune
# 25                      Pune
# 26     Bengaluru / Bangalore
# 27     Bengaluru / Bangalore
# 28                    Others
# 29                     Delhi
# 30     Bengaluru / Bangalore
# 31     Bengaluru / Bangalore
# 32           Mysoru / Mysore
# 33  Hyderabad / Secunderabad
# 34                 Ghaziabad
# 35     Bengaluru / Bangalore
# 36                     Noida
# 37                 New Delhi
# 38                   Chennai
# 39                   Aligarh
# 40            Salt Lake City
# 41                      Pune
# 42     Bengaluru / Bangalore
# 43                    Mumbai
# 44                    Indore
# 45     Bengaluru / Bangalore
# 46                    MYSORE
# 47  Hyderabad / Secunderabad
# 48     Bengaluru / Bangalore
# 49                    Mumbai

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)

# %%
#creating empty list for all the elements
rank=[]
book_names = []
author_names = []
volumes_sold = []
publisher = []
genre = []

#No need for exception handlnig as the data is in table format and all the data points are available to extract.
Rank_obj = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[1]')
for i in Rank_obj:
    rank.append(i.text)

    #NAME OF BOOK
    
Names_obj = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in Names_obj:
    book_names.append(i.text)

    #AUTHOR NAME
author_obj = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in author_obj:
    author_names.append(i.text)

        
    #VOLUME OF BOOKS SOLD
volume_obj = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in volume_obj:
    volumes_sold.append(i.text)

    #PUBLISHER NAME
publisher_obj = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in publisher_obj:
    publisher.append(i.text)

        
    #GENRE ELEMENT
genre_obj = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in genre_obj:
    genre.append(i.text)

# %%
#Creating a dictionary of all the elements
dict = {
   'Rank':rank, 'Book name':book_names,'Author name':author_names,'Volumes sold':volumes_sold,
    'Publisher':publisher,'Genre':genre
}
#Dataframe/Table creating of the dictionary
table = pd.DataFrame(dict)
table
# Out:
#    Rank                                          Book name       Author name  \
# 0     1                                  Da Vinci Code,The        Brown, Dan
# 1     2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2     3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3     4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4     5                               Fifty Shades of Grey      James, E. L.
# ..  ...                                                ...               ...
# 95   96                                          Ghost,The    Harris, Robert
# 96   97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97   98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 6 columns]

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
movies = []
year_span = []
genre = []
run_time = []
ratings = []
votes = []
#MOIVE NAME ELEMENT

movie_name_obj = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
for i in movie_name_obj:
    movies.append(i.text)

        
    #YEAR SPAN OBJECT

year_span_obj = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/span[2]')
for i in year_span_obj:
    year_span.append(i.text)

    #GENRE OBJECT

genre_obj = driver.find_elements_by_xpath('//span[@class="genre"]')
for i in genre_obj:
    genre.append(i.text)

        
    #RUNTIME ELEMENT
    
runtime_obj = driver.find_elements_by_xpath('//span[@class="runtime"]')
for i in runtime_obj:
    run_time.append(i.text)

    #RATING OBJECT
    
rating_obj = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]/span[2]')
for i in rating_obj:
    ratings.append(i.text)

    #NO OF VOTES OBJECT
       
votes_obj = driver.find_elements_by_xpath('//*[@id="main"]/div/div[3]/div[3]/div/div[2]/p[4]/span[2]')
for i in votes_obj:
    votes.append(i.text)

# %%
#creating a dictionary of all the elements
dict = {
    'Movie Name':movies,'Year Span':year_span,'Genre':genre,'Run time':run_time,
    'Rating':ratings,'Votes':votes
}
#data frame creation
table = pd.DataFrame(dict)
table
# Out:
#                         Movie Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Rating      Votes
# 0    57 min    9.2  1,882,042
# 1    51 min    8.7    915,485
# 2    44 min    8.2    903,992
# 3    60 min    7.5    270,865
# 4    43 min    7.6    231,254
# ..      ...    ...        ...
# 95   42 min    7.5     45,883
# 96   50 min    7.8     56,756
# 97   42 min    8.1    177,245
# 98   45 min    7.1     36,871
# 99  572 min    8.6    203,427
#
# [100 rows x 6 columns]

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver=webdriver.Chrome(r"C:\Rajashri\Iternship\Chromdriver\chromedriver.exe")
url = 'https://archive.ics.uci.edu/'
driver.get(url)
#repository element element object
repository_links = driver.find_elements_by_xpath('//span[@class="normal"]/a')
#al lthe repository element links
for i in repository_links:
    print(i.get_attribute('href'))
# Out:
# https://archive.ics.uci.edu/ml/index.html
# http://cml.ics.uci.edu/
# https://archive.ics.uci.edu/ml/about.html
# https://archive.ics.uci.edu/ml/citation_policy.html
# https://archive.ics.uci.edu/ml/donation_policy.html
# https://archive.ics.uci.edu/ml/contact.html
# http://archive.ics.uci.edu/ml/noteNetflix.txt
# https://archive.ics.uci.edu/ml/datasets/Kinship
# https://archive.ics.uci.edu/ml/datasets/Synchronous+Machine+Data+Set
# https://archive.ics.uci.edu/ml/datasets/Wikipedia+Math+Essentials
# https://archive.ics.uci.edu/ml/datasets/Wikipedia+Math+Essentials
# https://archive.ics.uci.edu/ml/datasets/Hungarian+Chickenpox+Cases
# https://archive.ics.uci.edu/ml/datasets/Myocardial+infarction+complications
# https://archive.ics.uci.edu/ml/datasets/Gait+Classification
# https://archive.ics.uci.edu/ml/datasets/Codon+usage
# https://archive.ics.uci.edu/ml/datasets/in-vehicle+coupon+recommendation
# https://archive.ics.uci.edu/ml/datasets/Dry+Bean+Dataset
# https://archive.ics.uci.edu/ml/datasets/Intelligent+Media+Accelerometer+and+Gyroscope+%28IM-AccGyro%29+Dataset
# https://archive.ics.uci.edu/ml/datasets/AI4I+2020+Predictive+Maintenance+Dataset
# https://archive.ics.uci.edu/ml/datasets/Wisesight+Sentiment+Corpus
# https://archive.ics.uci.edu/ml/datasets/Iris
# https://archive.ics.uci.edu/ml/datasets/Adult
# https://archive.ics.uci.edu/ml/datasets/Wine
# https://archive.ics.uci.edu/ml/datasets/Wine+Quality
# https://archive.ics.uci.edu/ml/datasets/Heart+Disease
# https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
# https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
# https://archive.ics.uci.edu/ml/datasets/Car+Evaluation
# https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones
# https://archive.ics.uci.edu/ml/datasets/Abalone
# https://archive.ics.uci.edu/ml/datasets/Forest+Fires
# https://archive.ics.uci.edu/ml/datasets/Student+Performance
# https://archive.ics.uci.edu/ml/about.html
# https://archive.ics.uci.edu/ml/citation_policy.html
# https://archive.ics.uci.edu/ml/donation_policy.html
# https://archive.ics.uci.edu/ml/contact.html
# http://cml.ics.uci.edu/

# %%
#Dataset URLS
urls = []
for i in repository_links:
    if(i.get_attribute('href').find('datasets')>0):
        urls.append(i.get_attribute('href'))
urls
# Out:
# ['https://archive.ics.uci.edu/ml/datasets/Kinship',
#  'https://archive.ics.uci.edu/ml/datasets/Synchronous+Machine+Data+Set',
#  'https://archive.ics.uci.edu/ml/datasets/Wikipedia+Math+Essentials',
#  'https://archive.ics.uci.edu/ml/datasets/Wikipedia+Math+Essentials',
#  'https://archive.ics.uci.edu/ml/datasets/Hungarian+Chickenpox+Cases',
#  'https://archive.ics.uci.edu/ml/datasets/Myocardial+infarction+complications',
#  'https://archive.ics.uci.edu/ml/datasets/Gait+Classification',
#  'https://archive.ics.uci.edu/ml/datasets/Codon+usage',
#  'https://archive.ics.uci.edu/ml/datasets/in-vehicle+coupon+recommendation',
#  'https://archive.ics.uci.edu/ml/datasets/Dry+Bean+Dataset',
#  'https://archive.ics.uci.edu/ml/datasets/Intelligent+Media+Accelerometer+and+Gyroscope+%28IM-AccGyro%29+Dataset',
#  'https://archive.ics.uci.edu/ml/datasets/AI4I+2020+Predictive+Maintenance+Dataset',
#  'https://archive.ics.uci.edu/ml/datasets/Wisesight+Sentiment+Corpus',
#  'https://archive.ics.uci.edu/ml/datasets/Iris',
#  'https://archive.ics.uci.edu/ml/datasets/Adult',
#  'https://archive.ics.uci.edu/ml/datasets/Wine',
#  'https://archive.ics.uci.edu/ml/datasets/Wine+Quality',
#  'https://archive.ics.uci.edu/ml/datasets/Heart+Disease',
#  'https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29',
#  'https://archive.ics.uci.edu/ml/datasets/Bank+Marketing',
#  'https://archive.ics.uci.edu/ml/datasets/Car+Evaluation',
#  'https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones',
#  'https://archive.ics.uci.edu/ml/datasets/Abalone',
#  'https://archive.ics.uci.edu/ml/datasets/Forest+Fires',
#  'https://archive.ics.uci.edu/ml/datasets/Student+Performance']

# %%
dataset_names = []
dataset_datatypes = []
tasks = []
attribute_types = []
no_instances = []
no_attributes = []
year = []


#Looping through the each dataset urls-> 

for i in urls:
    driver.get(i)
    
    #dataset name
    
    try:
        dataset_name_obj = driver.find_element_by_xpath('//span[@class="heading"]/b')
        dataset_names.append(dataset_name_obj.text)
    except:
        dataset_names.append('-')
       
    #DATA SET DATA TYPES
    try:
        dataset_datatype_obj = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[1]/td[2]/p')
        dataset_datatypes.append(dataset_datatype_obj.text)
    except:
        dataset_datatypes.append('-')
        
    #TASKS  
        
    try:
        dataset_task_obj = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[3]/td[2]/p')
        tasks.append(dataset_task_obj.text)
    except:
        tasks.append('-')
      
    #ATTRIBUTE TYPES
        
    try:
        dataset_attr_type_obj = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[2]/td[2]/p')
        attribute_types.append(dataset_attr_type_obj.text)
    except:
        attribute_types.append('-')
        
   
    #no of instances  
    try:
        dataset_instances_obj = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[1]/td[4]/p')
        no_instances.append(dataset_instances_obj.text)
    except:
        no_instances.append('-')
        
     #no of attributes   
        
    try:
        dataset_attr_obj = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[2]/td[4]/p')
        no_attributes.append(dataset_attr_obj.text)
    except:
        no_attributes.append('-')
    
      
    #year of DATASET
    try:
        year_obj = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/table[2]/tbody/tr[2]/td[6]/p')
        year.append(year_obj.text)
    except:
        year.append('-')

# %%
#creating a dictionary of all the elements
dict = {
    'Dataset name': dataset_names, 'Data type':dataset_datatypes,'Task':tasks,
    'Attribute type':attribute_types, 'No of instances':no_instances,
    'No of attribute':no_instances,'Year':year
}

#creating a Table from the dictionary
table = pd.DataFrame(dict)
table
# Out:
#                                          Dataset name  \
# 0                                    Kinship Data Set
# 1               Synchronous Machine Data Set Data Set
# 2                  Wikipedia Math Essentials Data Set
# 3                  Wikipedia Math Essentials Data Set
# 4                 Hungarian Chickenpox Cases Data Set
# 5        Myocardial infarction complications Data Set
# 6                        Gait Classification Data Set
# 7                                Codon usage Data Set
# 8           in-vehicle coupon recommendation Data Set
# 9                           Dry Bean Dataset Data Set
# 10  Intelligent Media Accelerometer and Gyroscope ...
# 11  AI4I 2020 Predictive Maintenance Dataset Data Set
# 12                Wisesight Sentiment Corpus Data Set
# 13                                      Iris Data Set
# 14                                     Adult Data Set
# 15                                      Wine Data Set
# 16                              Wine Quality Data Set
# 17                             Heart Disease Data Set
# 18      Breast Cancer Wisconsin (Diagnostic) Data Set
# 19                            Bank Marketing Data Set
# 20                            Car Evaluation Data Set
# 21  Human Activity Recognition Using Smartphones D...
# 22                                   Abalone Data Set
# 23                              Forest Fires Data Set
# 24                       Student Performance Data Set
#
#                     Data type                                          Task  \
# 0                  Relational                           Relational-Learning
# 1                Multivariate                                    Regression
# 2                 Time-Series                                    Regression
# 3                 Time-Series                                    Regression
# 4                 Time-Series                                    Regression
# 5                Multivariate                                Classification
# 6                Multivariate                                Classification
# 7                Multivariate                    Classification, Clustering
# 8                Multivariate                                Classification
# 9                Multivariate                                Classification
# 10                Time-Series                                Classification
# 11  Multivariate, Time-Series  Classification, Regression, Causal-Discovery
# 12         Multivariate, Text                                Classification
# 13               Multivariate                                Classification
# 14               Multivariate                                Classification
# 15               Multivariate                                Classification
# 16               Multivariate                    Classification, Regression
# 17               Multivariate                                Classification
# 18               Multivariate                                Classification
# 19               Multivariate                                Classification
# 20               Multivariate                                Classification
# 21  Multivariate, Time-Series                    Classification, Clustering
# 22               Multivariate                                Classification
# 23               Multivariate                                    Regression
# 24               Multivariate                    Classification, Regression
#
#                 Attribute type No of instances No of attribute        Year
# 0                  Categorical             104             104  1990-07-01
# 1                         Real             557             557  2021-04-21
# 2                         Real             731             731  2021-04-20
# 3                         Real             731             731  2021-04-20
# 4                         Real             521             521  2021-02-17
# 5                         Real            1700            1700  2020-12-09
# 6                         Real              48              48  2020-10-14
# 7                          N/A           13028           13028  2020-10-03
# 8                          N/A           12684           12684  2020-09-15
# 9                Integer, Real           13611           13611  2020-09-14
# 10                        Real             800             800  2020-09-03
# 11                        Real           10000           10000  2020-08-30
# 12                         N/A           26737           26737  2020-08-25
# 13                        Real             150             150  1988-07-01
# 14        Categorical, Integer           48842           48842  1996-05-01
# 15               Integer, Real             178             178  1991-07-01
# 16                        Real            4898            4898  2009-10-07
# 17  Categorical, Integer, Real             303             303  1988-07-01
# 18                        Real             569             569  1995-11-01
# 19                        Real           45211           45211  2012-02-14
# 20                 Categorical            1728            1728  1997-06-01
# 21                         N/A           10299           10299  2012-12-10
# 22  Categorical, Integer, Real            4177            4177  1995-12-01
# 23                        Real             517             517  2008-02-29
# 24                     Integer             649             649  2014-11-27
